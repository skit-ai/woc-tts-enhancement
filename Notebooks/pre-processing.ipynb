# %%
import numpy as np
import os
import pandas as pd

df = pd.read_csv("tts_data.csv") #differece = Train - Gen
df
# Out:
#        Unnamed: 0          Train_filename                 Gen_filename  \
# 0               0     b-4_151-300_163.wav     VTTS_b-4_151-300_163.wav
# 1               1  b-3_5639-5744_5658.wav  VTTS_b-3_5639-5744_5658.wav
# 2               2  b-3_6016-6115_6028.wav  VTTS_b-3_6016-6115_6028.wav
# 3               3  b-4_2000-5164_3435.wav  VTTS_b-4_2000-5164_3435.wav
# 4               4  b-3_4607-5008_4801.wav  VTTS_b-3_4607-5008_4801.wav
# ...           ...                     ...                          ...
# 19176       19176  b-2_1903-2038_1988.wav  VTTS_b-2_1903-2038_1988.wav
# 19177       19177  b-1_3834-3934_3909.wav  VTTS_b-1_3834-3934_3909.wav
# 19178       19178  b-4_2000-5164_4029.wav  VTTS_b-4_2000-5164_4029.wav
# 19179       19179    b-2_917-1018_923.wav    VTTS_b-2_917-1018_923.wav
# 19180       19180  b-3_3803-3888_3854.wav  VTTS_b-3_3803-3888_3854.wav
#
#        Train_duration  Gen_duration  Difference
# 0                4060          3587         473
# ...

# %%
df["Difference"].describe()
# Out:
# count    19181.000000
# mean      -115.034670
# std        924.949708
# min     -10380.000000
# 25%       -270.000000
# 50%         26.000000
# 75%        249.000000
# max       7720.000000
# Name: Difference, dtype: float64
